# %%
# Data Types
#1) Numeric Type

# 1) int

num1 = 100;
num2 =200;
res = num1 + num2
print(res)


# 2) Numeric Type

num3 = 10.3456
num4 = 9.87
floatres = num3 - num4
print(floatres)


#3 Complex

num5 = 2+3j
num6 = 4+6j
compres = num5 + num6;
print(compres)


# 2) Text type

name = 'harsh';
collage = "gov eng";
graduation = '''betch''';

print(name,collage,graduation);


# 3) boolean
ispresent = True;
iseligible = False;

print(type(ispresent));
print(type(iseligible));
# Out:
# 300
# 0.4756
# (6+9j)
# harsh gov eng betch
# <class 'bool'>
# <class 'bool'>
