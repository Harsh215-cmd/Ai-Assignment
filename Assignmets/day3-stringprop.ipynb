# %% [markdown]
# ### Immutability

# %%
str1="hello world"
print(str1)

print(str1[0])
# Out:
# hello world
# h

# %% [markdown]
# ### Concentation

# %%
str1 = "Harsh"
str2 = "ghorpade"

fullname = str1 + str2
print(fullname)

# %% [markdown]
# ### Repetition

# %%
str1="hello "
reapited=str1*10;
print(reapited)
# Out:
# hello hello hello hello hello hello hello hello hello hello

# %% [markdown]
# ### in/ not in

# %%
str1="i love my india"
print("love" in str1 )
print("harsh" in str1)

print("harsh" not in str1)
# Out:
# True
# False
# True
