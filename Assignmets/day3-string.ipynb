# %%
name = "harshal";
print("0th index of given string :",name[0])
# Out:
# 0th index of given string : h

# %% [markdown]
# ## String

# %%
name="harshal"
branch = 'cse'

print(name,branch)
# Out:
# harshal cse

# %% [markdown]
# ## Multiline

# %%
introduction='''my name is harsh ,
i complet my graduation in 2023 in 
at gov engineering ytl with cgpa 0f 8.5'''

skills = """i know html , css , js , react, for frontend
node and express for backend 
mongodb as database"""

print(introduction);
print(skills)
# Out:
# my name is harsh , i complet
# my graduation in 2023 in at gov engineering ytl
# with cgpa 0f 8.5

# %% [markdown]
# ## multiline using single and double quate

# %%
introduction="my name is harsh\
i complet my graduation in 2023 in\
at gov engineering ytl with cgpa 0f 8.5"

print(introduction)
# Out:
# my name is harshi complet my graduation in 2023 inat gov engineering ytl with cgpa 0f 8.5

# %% [markdown]
# # indexing

# %%
#positive indexing
string = "welcome to india"
print(string[0],string[1],string[3],string[4])

#negative indexing
print(string[-1],string[-2],string[-3],string[-4],string[-5])
# Out:
# w e c o
# a i d n i
