# %%
#operator
#1) arithatic operator
# +,-,*,//,/,%

# %%
num1 = 10;
num2 = 20;
res = num1 +num2;
print("addition of num1  and num2 is :", res)
# Out:
# addition of num one and num2 is : 30

# %%
num1 = 80;
num2 = 60;
res = num1 * num2;
print("Multiplication of num1 and num2 is :", res)
# Out:
# Multiplication of num1 and num2 is : 4800

# %%
num1 = 60;
num2 = 19;
res = num1  // num2;
print("disvision of num1 and num2 is :", res)
# Out:
# disvision of num one and num2 is : 3

# %%
num1 = 60;
num2 = 19;
res = num1 / num2;
print("Division of num1 and num2 in float :", res)
# Out:
# Division of num one and num2 in float : 3.1578947368421053

# %%
num1 = 90;
num2 = 26;
res = num1 - num2;
print("substraction of num1 and num2 is :", res)
# Out:
# substraction of num1 and num2 is : 64

# %%
num1 = 90;
num2 = 26;
res = num1 % num2;
print("Modulas of num1 and num2 is :", res)
# Out:
# Modulas of num1 and num2 is : 12

# %%
num1 = 11;
num2 = 2;
res = num1 ** num2;
print("squar of",num1 , "is ", res)
# Out:
# Asuare of 11 is  121

# %%
# Precedenc
res = (10 + 20) * (40-20)
print(res);
# Out:
# 600

# %%
#type Conersion
# float to int

num1 = 10.99
num2 = int(num1)
print("before converion: ",type(num1))
print("after converion: ",type(num2))
# Out:
# before converion:  <class 'float'>
# after converion:  <class 'int'>

# %%
# String to int
num1 = "10"
num2 = int(num1);
print(type(num1))
print(type(num2))
# Out:
# <class 'str'>
# <class 'int'>

# %%
# boolean to int
ispresent = True;
conv = int(ispresent);

print("before conversion",type(ispresent));
print("after conversion",type(conv));
# Out:
# before conversion <class 'bool'>
# after conversion <class 'int'>
