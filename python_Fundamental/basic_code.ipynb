# %%
print("hello")
# Out:
# hello

# %%
# a@=44;
# print(a@);

# %%
num1 = 10.10
num2 = 11.11
res = num1+num2
print(res)
# Out:
# 21.21

# %%
name= "harsh"
surname= 'ghorpade'
print(type(name));
print(type(surname))
# Out:
# <class 'str'>

# %%
# pi_exp=3.142e
# print(type(pi_exp));

# %%
isPresent=True;
print(type(isPresent));
# Out:
# <class 'bool'>

# %%
name="harsh";
collage='govt eng'
graduation='''cse'''


print(name,collage,graduation);
print(type(name))
print(type(collage))
print(type(graduation))
# Out:
# harsh govt eng cse
# <class 'str'>

# %%
name,age,weight,num,iseligible="Harsh",23,55.50,1,True;
print( name,",",age, "," ,weight, "," ,num ,"," ,iseligible)
# Out:
# Harsh , 23 , 55.5 , 1 , True

# %%
# Arithmatic operator

a=10;
b=20;
c= a+b;

print(id(a))
print("num 1", a);
print("num 2",b);
print("addition :",c , "and adress is :", id(c));
# Out:
# 140729874744728
# num 1 10
# num 2 20
# addition : 30 and adress is : 140729874745368

# %%
#substraction

num1 = 200
num2 = 100
res = num1 - num2
print(res)
# Out:
# 100

# %%
#multiplication

num1 = 85
num2 = 10
res = num1 * num2
print(res)
# Out:
# 850

# %%
#division  floating

num1 = 90
num2 = 15
res = num1 // num2
print(res)
# Out:
# 6

# %%
#division 

num1 = 92
num2 = 15
res = num1 / num2
print(res)
# Out:
# 6.133333333333334

# %%
#exponential

num1 = 11;
num2 = 2;

res = num1 ** num2
print(res)
# Out:
# 121

# %%
#Precedence

res = (2+3)*3
print(res)

res2 = 2+3**2
print(res2)
# Out:
# 15
# 11

# %%
#type conversion

#string
num = "10"
print("num is",num ,"type is" ,type(num))
print("after coversion :", int(num), "type is :", type(int(num)))
# Out:
# num is 10 type is <class 'str'>
# after coversion : 10 type is : <class 'int'>

# %%
#float 

num = 10.678

res = int(num);

print(res)
# Out:
# 10

# %%
# boolean
ispresent = True
iseligible = False

print(type(int(ispresent)))
print(type(int(iseligible)))
# Out:
# <class 'int'>
# <class 'int'>
